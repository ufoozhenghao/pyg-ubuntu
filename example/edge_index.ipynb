                           [41,42],[41,31],[41,121],[41,51],[41,222],
                           [42,41],[42,43],[42,32],[42,122],[42,52],[42,222],
                           [43,44],[43,42],[43,45],[43,33],[43,123],[43,53],[43,221],
                           [44,43],[44,34],[44,124],[44,54],[44,221],
                           [45,46],[45,43],
                           [46,45],
                           [51,52],[51,41],[51,61],[51,121],[51,131],
                           [52,51],[52,53],[52,42],[52,62],[52,122],[52,132],
                           [53,52],[53,54],[53,55],[53,43],[53,63],[53,123],[53,133],
                           [54,53],[54,44],[54,124],[54,134],[54,64],
                           [55,53],[55,56],
                           [56,55],
                           [61,62],[61,51],[61,131],[61,71],
                           [62,61],[62,63],[62,52],[62,152],[62,132],[62,72],
                           [63,62],[63,64],[63,65],[63,53],[63,133],[63,73],
                           [64,63],[64,54],[64,134],[64,74],
                           [65,66],[65,64],
                           [66,65],
                           [71,72],[71,61],[71,131],[71,141],[71,91],[71,81],
                           [72,71],[72,73],[72,62],[72,132],[72,142],[72,92],[72,82],
                           [73,72],[73,74],[73,75],[73,63],[73,133],[73,143],[73,93],[73,83],
                           [74,73],[74,64],[74,134],[74,144],[74,94],[74,84],
                           [75,76],[75,73],
                           [76,75],
                           [81,82],[81,71],[81,141],[81,91],[81,11],
                           [82,81],[82,83],[82,72],[82,142],[82,92],[82,12],
                           [83,82],[83,94],[83,95],[83,73],[83,143],[83,93],[83,13],
                           [84,83],[84,74],[84,144],[84,94],[84,14],
                           [85,84],[85,86],
                           [86,85],
                           [211,63],[211,64],[211,134],[211,133],
                           [212,61],[212,62],[212,131],[212,132]], dtype=torch.long)

# %% [markdown]
# ### 原始节点ID列表
# original_ids = [2, 5, 6, 9]
#
# ### 从原始ID到新ID的映射
# id_to_new = {original_id: new_id for new_id, original_id in enumerate(original_ids)}
#
# ### 从新ID到原始ID的映射
# new_to_id = {new_id: original_id for original_id, new_id in id_to_new.items()}
#
# print("原始到新的ID映射:", id_to_new)
# print("新到原始的ID映射:", new_to_id)
#
# ### 节点5和节点6的连接
# original_connection = (5, 6)
#
# ### 转换为新ID
# new_connection = (id_to_new[original_connection[0]], id_to_new[original_connection[1]])
#
# print("原始连接:", original_connection, "-> 新连接:", new_connection)

# %%
# 提取所有独特的节点ID
unique_node_ids = torch.unique(edge_index).numpy()
print("unique_node_ids:\n", unique_node_ids)
print("\n")
# 创建原始ID到新ID的映射
node_id_to_new_id = {original_id: new_id for new_id, original_id in enumerate(unique_node_ids)}
print("新的 node_id_to_new_id:\n", node_id_to_new_id)
# Out:
# unique_node_ids:
#  [ 11  12  13  14  15  16  21  22  23  24  25  26  31  32  33  34  35  36
#   41  42  43  44  45  46  51  52  53  54  55  56  61  62  63  64  65  66
#   71  72  73  74  75  76  81  82  83  84  85  86  91  92  93  94  95 100
#  101 102 103 104 105 111 112 113 114 121 122 123 124 131 132 133 134 141
#  142 143 144 150 151 152 153 154 155 211 212 221 222]
#
#
# 新的 node_id_to_new_id:
# ...

# %%
# 更新 edge_index
new_edge_index = torch.tensor([[node_id_to_new_id[node_id.item()] for node_id in edge] for edge in edge_index])

print("新的 edge_index:\n", new_edge_index)
# Out:
# 新的 edge_index:
#  tensor([[75, 76],
#         [75, 80],
#         [75, 53],
#         [75, 58],
#         [80, 75],
#         [80, 58],
#         [80, 53],
#         [76, 75],
#         [76, 77],
#         [76, 48],
#         [76, 54],
#         [76, 71],
#         [76, 59],
#         [76, 63],
#         [76, 67],
#         [76,  0],
#         [76, 24],
#         [77, 76],
#         [77, 78],
#         [77, 49],
#         [77, 55],
#         [77, 60],
#         [77, 64],
#         [77, 68],
#         [77, 72],
#         [77,  1],
#         [77, 25],
#         [78, 77],
#         [78, 79],
#         [78, 50],
#         [78, 56],
#         [78, 61],
#         [78, 65],
#         [78, 69],
#         [78, 73],
#         [78,  2],
#         [78, 26],
#         [79, 78],
#         [79, 51],
#         [79, 57],
#         [79, 62],
#         [79, 66],
#         [79, 70],
#         [79, 74],
#         [79, 27],
#         [79,  3],
#         [48, 49],
#         [48, 42],
#         [48,  0],
# ...

# %%
import pandas as pd

# 读取CSV文件
df = pd.read_csv('./data/temp_test.csv')

print(df.head())
# Out:
#    csv_node_id cs_stage  count  time  temp
# 0            1      CS1      1    12  10.0
# 1            2      CS1      1    12  10.0
# 2            3      CS1      1    12  10.0
# 3            4      CS1      1    12  10.0
# 4            9      CS1      1    12  10.0

# %%
# 创建映射字典
# 假设是从320开始，根即unique_node_ids  每次递增1映射到从0开始，每次递增1，一共映射84个
# 定义映射起始点
start_id = 320
csv_node_id_to_original_id = {start_id + i: unique_node_ids[i] for i in range(len(unique_node_ids))}
print(csv_node_id_to_original_id)
# Out:
# {320: 11, 321: 12, 322: 13, 323: 14, 324: 15, 325: 16, 326: 21, 327: 22, 328: 23, 329: 24, 330: 25, 331: 26, 332: 31, 333: 32, 334: 33, 335: 34, 336: 35, 337: 36, 338: 41, 339: 42, 340: 43, 341: 44, 342: 45, 343: 46, 344: 51, 345: 52, 346: 53, 347: 54, 348: 55, 349: 56, 350: 61, 351: 62, 352: 63, 353: 64, 354: 65, 355: 66, 356: 71, 357: 72, 358: 73, 359: 74, 360: 75, 361: 76, 362: 81, 363: 82, 364: 83, 365: 84, 366: 85, 367: 86, 368: 91, 369: 92, 370: 93, 371: 94, 372: 95, 373: 100, 374: 101, 375: 102, 376: 103, 377: 104, 378: 105, 379: 111, 380: 112, 381: 113, 382: 114, 383: 121, 384: 122, 385: 123, 386: 124, 387: 131, 388: 132, 389: 133, 390: 134, 391: 141, 392: 142, 393: 143, 394: 144, 395: 150, 396: 151, 397: 152, 398: 153, 399: 154, 400: 155, 401: 211, 402: 212, 403: 221, 404: 222}

# %%
# 将csv_node_id映射到原始node_id，然后转换到新的ID系统
df['original_id'] = df['csv_node_id'].map(csv_node_id_to_original_id).astype('Int64')
df['new_id'] = df['csv_node_id'].map(csv_node_id_to_original_id).map(node_id_to_new_id).astype('Int64')
print(df.iloc[315:400])
# print(df.head())
# Out:
#      csv_node_id cs_stage  count  time       temp  original_id  new_id
# 315          320      CS1      1    12  10.000283           11       0
# 316          321      CS1      1    12  10.000557           12       1
# 317          322      CS1      1    12  10.000744           13       2
# 318          323      CS1      1    12  10.000837           14       3
# 319          324      CS1      1    12  10.000835           15       4
# ..           ...      ...    ...   ...        ...          ...     ...
# 395          400      CS1      1    12  10.000833          155      80
# 396          401      CS1      1    12  10.000000          211      81
# 397          402      CS1      1    12  10.000001          212      82
# 398          403      CS1      1    12  10.000093          221      83
# 399          404      CS1      1    12  10.000274          222      84
#
# [85 rows x 7 columns]
